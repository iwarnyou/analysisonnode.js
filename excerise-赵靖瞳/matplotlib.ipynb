# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# 创建一个包含1000个点的线性空间，范围从0到10
# 这个数组将用于生成x轴的数据点
x = np.linspace(0, 10, 10000)
# 计算y值，公式为 y = sin(x) + 2
# 这里使用numpy的sin函数对x中的每个元素求正弦值，并加2
y = np.sin(x) + 2
# 绘制图形
# 使用plt.plot绘制x和y的关系图
# plt.show()用于显示图形
plt.plot(x, y)
plt.savefig("sin.pdf", dpi=100)

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid(True)
ax.set(xlabel="x", ylabel="sin(x)+2")
fig.savefig("sin.png", dpi=100)

# %%
norm = np.random.randn(10000) * 5 + 10
plt.hist(norm, 20)
plt.grid(True)
plt.xlabel("x")
plt.ylabel("randn(10000) * 5 + 10")
# Out:
# Text(0, 0.5, 'randn(10000) * 5 + 10')

# %%
sizes = [10, 20, 15, 5]
labels = ["sing", "dance", "rap", "basketball"]
explodes = [0, 0, 0.1, 0]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, explode=explodes)
ax.axis("equal")
fig.savefig("skill.png", dpi=50)

# %%
x = np.arange(0, 10, 0.01)
y = np.sin(x) + 2
fig, ax = plt.subplots(2, 2)
# ax[0][0] ax[0][1] ax[1][0] ax[1][1]
ax[0][0].plot(x, x)
ax[0][1].semilogx(x, y)
ax[1][0].semilogy(x, x)
ax[1][1].loglog(x, y)
